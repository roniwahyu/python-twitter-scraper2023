# %% [markdown]
# # Crawl Data Twitter > 1500 Tweets
# The crawling process was done using Tweet-Harvest. Written by Helmi Satria on October 18th.

# %%
# https://helmisatria.com/blog/cara-mendapatkan-data-twitter-yang-besar

# %%
#@title Twitter Auth Token

twitter_auth_token = 'replace_with_your_twitter_auth_token_here'

# %%
# Import required Python package
# !pip install pandas

# Install Node.js (because tweet-harvest built using Node.js)
# !sudo apt-get update
# !sudo apt-get install -y ca-certificates curl gnupg
# !sudo mkdir -p /etc/apt/keyrings
# !curl -fsSL https://deb.nodesource.com/gpgkey/nodesource-repo.gpg.key | sudo gpg --dearmor -o /etc/apt/keyrings/nodesource.gpg

# !NODE_MAJOR=20 && echo "deb [signed-by=/etc/apt/keyrings/nodesource.gpg] https://deb.nodesource.com/node_$NODE_MAJOR.x nodistro main" | sudo tee /etc/apt/sources.list.d/nodesource.list

# !sudo apt-get update
# !sudo apt-get install nodejs -y

# !node -v
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (1.5.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.23.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Get:1 http://security.ubuntu.com/ubuntu jammy-security InRelease [110 kB]
# Get:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,626 B]
# Hit:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:4 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:5 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [1,082 kB]
# Get:6 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [119 kB]
# Get:7 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,005 kB]
# Get:8 https://ppa.launchpadcontent.net/c2d4u.team/c2d4u4.0+/ubuntu jammy InRelease [18.1 kB]
# Get:9 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [109 kB]
# Get:10 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,270 kB]
# Hit:11 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Get:12 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [1,347 kB]
# Hit:13 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:14 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:15 https://ppa.launchpadcontent.net/c2d4u.team/c2d4u4.0+/ubuntu jammy/main Sources [2,224 kB]
# Get:16 https://ppa.launchpadcontent.net/c2d4u.team/c2d4u4.0+/ubuntu jammy/main amd64 Packages [1,140 kB]
# Fetched 8,427 kB in 5s (1,805 kB/s)
# Reading package lists... Done
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# ca-certificates is already the newest version (20230311ubuntu0.22.04.1).
# curl is already the newest version (7.81.0-1ubuntu1.14).
# gnupg is already the newest version (2.2.27-3ubuntu2.1).
# gnupg set to manually installed.
# 0 upgraded, 0 newly installed, 0 to remove and 28 not upgraded.
# deb [signed-by=/etc/apt/keyrings/nodesource.gpg] https://deb.nodesource.com/node_20.x nodistro main
# Hit:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Get:3 https://deb.nodesource.com/node_20.x nodistro InRelease [12.1 kB]
# Hit:4 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:5 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Get:6 https://deb.nodesource.com/node_20.x nodistro/main amd64 Packages [3,079 B]
# Hit:7 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:8 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:9 https://ppa.launchpadcontent.net/c2d4u.team/c2d4u4.0+/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:11 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:12 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Fetched 15.2 kB in 2s (7,972 B/s)
# Reading package lists... Done
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   nodejs
# 0 upgraded, 1 newly installed, 0 to remove and 28 not upgraded.
# Need to get 31.1 MB of archives.
# After this operation, 195 MB of additional disk space will be used.
# Get:1 https://deb.nodesource.com/node_20.x nodistro/main amd64 nodejs amd64 20.8.1-1nodesource1 [31.1 MB]
# Fetched 31.1 MB in 1s (58.7 MB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package nodejs.
# (Reading database ... 120875 files and directories currently installed.)
# Preparing to unpack .../nodejs_20.8.1-1nodesource1_amd64.deb ...
# Unpacking nodejs (20.8.1-1nodesource1) ...
# Setting up nodejs (20.8.1-1nodesource1) ...
# Processing triggers for man-db (2.10.2-1) ...
# v20.8.1

# %%
# Crawl Data

filename = 'gibran.csv'
search_keyword = 'gibran lang:id'
limit = 1500

# !npx --yes tweet-harvest@2.2.8 -o "{filename}" -s "{search_keyword}" -l {limit} --token {twitter_auth_token}
# Out:
# Welcome to the Twitter Crawler 🕷️
#
# This script uses Chromium Browser to crawl data from Twitter with *your* Twitter auth token.
# Please enter your Twitter auth token when prompted.
#
# Note: Keep your access token secret! Don't share it with anyone else.
# Note: This script only runs on your local device.
#
#
# up to date, audited 4 packages in 461ms
#
# found 0 vulnerabilities
# Installing dependencies...
# Hit:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:3 https://deb.nodesource.com/node_20.x nodistro InRelease
# Hit:4 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:5 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:6 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:7 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:8 https://ppa.launchpadcontent.net/c2d4u.team/c2d4u4.0+/ubuntu jammy InRelease
# Hit:9 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:11 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Reading package lists... Done
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# fonts-freefont-ttf is already the newest version (20120503-10build1).
# fonts-liberation is already the newest version (1:1.07.4-11).
# libasound2 is already the newest version (1.2.6.1-1ubuntu1).
# libatk-bridge2.0-0 is already the newest version (2.38.0-3).
# libatk1.0-0 is already the newest version (2.36.0-3build1).
# libatspi2.0-0 is already the newest version (2.44.0-3).
# libcairo2 is already the newest version (1.16.0-5ubuntu2).
# libfontconfig1 is already the newest version (2.13.1-4.2ubuntu5).
# libnspr4 is already the newest version (2:4.32-3build1).
# libxcb1 is already the newest version (1.14-3ubuntu3).
# libxcomposite1 is already the newest version (1:0.4.5-1build2).
# libxdamage1 is already the newest version (1:1.1.5-2build2).
# libxext6 is already the newest version (2:1.3.4-1build1).
# libxfixes3 is already the newest version (1:6.0.0-1).
# libxkbcommon0 is already the newest version (1.4.0-1).
# libxrandr2 is already the newest version (2:1.5.2-1build1).
# xfonts-scalable is already the newest version (1:1.0.3-1.2ubuntu1).
# fonts-ipafont-gothic is already the newest version (00303-21ubuntu1).
# fonts-tlwg-loma-otf is already the newest version (1:0.7.3-1).
# fonts-unifont is already the newest version (1:14.0.01-1).
# fonts-wqy-zenhei is already the newest version (0.9.45-8).
# xfonts-cyrillic is already the newest version (1:1.0.5).
# fonts-noto-color-emoji is already the newest version (2.038-0ubuntu1).
# libcups2 is already the newest version (2.4.1op1-1ubuntu4.7).
# libdbus-1-3 is already the newest version (1.12.20-2ubuntu4.1).
# libdrm2 is already the newest version (2.4.113-2~ubuntu0.22.04.1).
# libfreetype6 is already the newest version (2.11.1+dfsg-1ubuntu0.2).
# libgbm1 is already the newest version (23.0.4-0ubuntu1~22.04.1).
# libglib2.0-0 is already the newest version (2.72.4-0ubuntu2.2).
# libnss3 is already the newest version (2:3.68.2-0ubuntu1.2).
# libpango-1.0-0 is already the newest version (1.50.6+ds-2ubuntu1).
# libwayland-client0 is already the newest version (1.20.0-1ubuntu0.1).
# libx11-6 is already the newest version (2:1.7.5-1ubuntu0.3).
# xvfb is already the newest version (2:21.1.4-2ubuntu1.7~22.04.1).
# 0 upgraded, 0 newly installed, 0 to remove and 28 not upgraded.
# Downloading Chromium 119.0.6045.9 (playwright build v1084) from https://playwright.azureedge.net/builds/chromium/1084/chromium-linux.zip
# 155.8 Mb [] 0% 0.0s155.8 Mb [] 0% 40.1s155.8 Mb [] 0% 36.2s155.8 Mb [] 0% 25.9s155.8 Mb [] 0% 18.5s155.8 Mb [] 0% 14.2s155.8 Mb [] 1% 11.9s155.8 Mb [] 1% 9.7s155.8 Mb [] 1% 8.2s155.8 Mb [] 2% 7.8s155.8 Mb [] 2% 7.5s155.8 Mb [] 2% 7.0s155.8 Mb [] 3% 7.1s155.8 Mb [] 3% 6.7s155.8 Mb [] 3% 6.3s155.8 Mb [] 4% 6.1s155.8 Mb [] 5% 5.9s155.8 Mb [] 5% 5.5s155.8 Mb [] 6% 5.2s155.8 Mb [] 7% 5.1s155.8 Mb [] 7% 4.9s155.8 Mb [] 8% 4.7s155.8 Mb [] 9% 4.6s155.8 Mb [] 9% 4.5s155.8 Mb [] 10% 4.3s155.8 Mb [] 10% 4.2s155.8 Mb [] 11% 4.1s155.8 Mb [] 11% 4.0s155.8 Mb [] 12% 4.1s155.8 Mb [] 12% 4.0s155.8 Mb [] 13% 3.9s155.8 Mb [] 14% 3.8s155.8 Mb [] 14% 3.7s155.8 Mb [] 15% 3.7s155.8 Mb [] 15% 3.9s155.8 Mb [] 16% 3.7s155.8 Mb [] 17% 3.6s155.8 Mb [] 18% 3.4s155.8 Mb [] 19% 3.4s155.8 Mb [] 20% 3.3s155.8 Mb [] 20% 3.2s155.8 Mb [] 21% 3.2s155.8 Mb [] 22% 3.1s155.8 Mb [] 23% 3.0s155.8 Mb [] 23% 2.9s155.8 Mb [] 24% 2.9s155.8 Mb [] 25% 2.8s155.8 Mb [] 26% 2.7s155.8 Mb [] 27% 2.7s155.8 Mb [] 28% 2.6s155.8 Mb [] 29% 2.5s155.8 Mb [] 30% 2.4s155.8 Mb [] 31% 2.3s155.8 Mb [] 32% 2.3s155.8 Mb [] 33% 2.2s155.8 Mb [] 34% 2.2s155.8 Mb [] 35% 2.1s155.8 Mb [] 36% 2.1s155.8 Mb [] 37% 2.0s155.8 Mb [] 38% 2.0s155.8 Mb [] 39% 1.9s155.8 Mb [] 40% 1.9s155.8 Mb [] 41% 1.8s155.8 Mb [] 42% 1.8s155.8 Mb [] 43% 1.7s155.8 Mb [] 44% 1.7s155.8 Mb [] 45% 1.6s155.8 Mb [] 46% 1.6s155.8 Mb [] 47% 1.6s155.8 Mb [] 48% 1.5s155.8 Mb [] 49% 1.5s155.8 Mb [] 50% 1.4s155.8 Mb [] 51% 1.4s155.8 Mb [] 52% 1.4s155.8 Mb [] 53% 1.3s155.8 Mb [] 54% 1.3s155.8 Mb [] 55% 1.3s155.8 Mb [] 56% 1.2s155.8 Mb [] 58% 1.2s155.8 Mb [] 59% 1.1s155.8 Mb [] 60% 1.1s155.8 Mb [] 62% 1.0s155.8 Mb [] 63% 1.0s155.8 Mb [] 64% 0.9s155.8 Mb [] 65% 0.9s155.8 Mb [] 66% 0.9s155.8 Mb [] 67% 0.8s155.8 Mb [] 68% 0.8s155.8 Mb [] 69% 0.8s155.8 Mb [] 70% 0.8s155.8 Mb [] 71% 0.8s155.8 Mb [] 71% 0.7s155.8 Mb [] 72% 0.7s155.8 Mb [] 73% 0.7s155.8 Mb [] 74% 0.7s155.8 Mb [] 75% 0.6s155.8 Mb [] 76% 0.6s155.8 Mb [] 77% 0.6s155.8 Mb [] 78% 0.6s155.8 Mb [] 79% 0.6s155.8 Mb [] 79% 0.5s155.8 Mb [] 80% 0.5s155.8 Mb [] 81% 0.5s155.8 Mb [] 82% 0.5s155.8 Mb [] 83% 0.5s155.8 Mb [] 84% 0.4s155.8 Mb [] 85% 0.4s155.8 Mb [] 86% 0.4s155.8 Mb [] 87% 0.3s155.8 Mb [] 88% 0.3s155.8 Mb [] 89% 0.3s155.8 Mb [] 90% 0.3s155.8 Mb [] 91% 0.2s155.8 Mb [] 92% 0.2s155.8 Mb [] 93% 0.2s155.8 Mb [] 94% 0.1s155.8 Mb [] 95% 0.1s155.8 Mb [] 96% 0.1s155.8 Mb [] 97% 0.1s155.8 Mb [] 98% 0.0s155.8 Mb [] 99% 0.0s155.8 Mb [] 100% 0.0s
# Chromium 119.0.6045.9 (playwright build v1084) downloaded to /root/.cache/ms-playwright/chromium-1084
# Downloading FFMPEG playwright build v1009 from https://playwright.azureedge.net/builds/ffmpeg/1009/ffmpeg-linux.zip
# 2.6 Mb [] 0% 0.0s2.6 Mb [] 2% 0.8s2.6 Mb [] 5% 0.8s2.6 Mb [] 10% 0.6s2.6 Mb [] 21% 0.3s2.6 Mb [] 37% 0.2s2.6 Mb [] 49% 0.1s2.6 Mb [] 69% 0.1s2.6 Mb [] 92% 0.0s2.6 Mb [] 100% 0.0s
# FFMPEG playwright build v1009 downloaded to /root/.cache/ms-playwright/ffmpeg-1009
#
# Opening twitter search page...
#
#
# Filling in keywords: gibran
#
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/gibran.csv
# Total tweets saved: 13
# Scrolling more...
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/gibran.csv
# Total tweets saved: 23
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/gibran.csv
# Total tweets saved: 32
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/gibran.csv
# Total tweets saved: 42
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/gibran.csv
# Total tweets saved: 55
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/gibran.csv
# Total tweets saved: 61
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/gibran.csv
# Total tweets saved: 71
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/gibran.csv
# Total tweets saved: 84
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/gibran.csv
# Total tweets saved: 96
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/gibran.csv
# Total tweets saved: 106
#
# --Taking a break, waiting for 10 seconds...
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/gibran.csv
# Total tweets saved: 114
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/gibran.csv
# Total tweets saved: 123
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/gibran.csv
# Total tweets saved: 136
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/gibran.csv
# Total tweets saved: 149
# Scrolling more...
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/gibran.csv
# Total tweets saved: 167
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/gibran.csv
# Total tweets saved: 180
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/gibran.csv
# Total tweets saved: 191
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/gibran.csv
# Total tweets saved: 203
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/gibran.csv
# Total tweets saved: 214
#
# --Taking a break, waiting for 10 seconds...
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/gibran.csv
# Total tweets saved: 227
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/gibran.csv
# Total tweets saved: 241
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/gibran.csv
# Total tweets saved: 252
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/gibran.csv
# Total tweets saved: 262
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/gibran.csv
# Total tweets saved: 274
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/gibran.csv
# Total tweets saved: 289
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/gibran.csv
# Total tweets saved: 303
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/gibran.csv
# Total tweets saved: 316
#
# --Taking a break, waiting for 10 seconds...
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/gibran.csv
# Total tweets saved: 329
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/gibran.csv
# Total tweets saved: 343
# Scrolling more...
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/gibran.csv
# Total tweets saved: 357
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/gibran.csv
# Total tweets saved: 371
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/gibran.csv
# Total tweets saved: 387
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/gibran.csv
# Total tweets saved: 401
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/gibran.csv
# Total tweets saved: 415
# Scrolling more...
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/gibran.csv
# Total tweets saved: 427
#
# --Taking a break, waiting for 10 seconds...
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/gibran.csv
# Total tweets saved: 441
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/gibran.csv
# Total tweets saved: 458
# Scrolling more...
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/gibran.csv
# Total tweets saved: 475
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/gibran.csv
# Total tweets saved: 490
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/gibran.csv
# Total tweets saved: 508
# Scrolling more...
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/gibran.csv
# Total tweets saved: 523
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/gibran.csv
# Total tweets saved: 536
#
# --Taking a break, waiting for 10 seconds...
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/gibran.csv
# Total tweets saved: 549
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/gibran.csv
# Total tweets saved: 561
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/gibran.csv
# Total tweets saved: 573
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/gibran.csv
# Total tweets saved: 584
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/gibran.csv
# Total tweets saved: 600
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/gibran.csv
# Total tweets saved: 613
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/gibran.csv
# Total tweets saved: 627
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/gibran.csv
# Total tweets saved: 645
#
# --Taking a break, waiting for 10 seconds...
#
# Got some tweets, saving to file...
# Error parsing response json: {"_type":"Response","_guid":"response@5aca6032e3e85f11af47b6eb9f624ccf"}
# Most likely, you have already exceeded the Twitter rate limit. Read more on https://twitter.com/elonmusk/status/1675187969420828672?s=46.
#
# Got some tweets, saving to file...
# Error parsing response json: {"_type":"Response","_guid":"response@5f34e7528685414f0e1e88295320064a"}
# Most likely, you have already exceeded the Twitter rate limit. Read more on https://twitter.com/elonmusk/status/1675187969420828672?s=46.
#
# Got some tweets, saving to file...
# Error parsing response json: {"_type":"Response","_guid":"response@ac44e0ba31fe3bca554221da3949c00f"}
# Most likely, you have already exceeded the Twitter rate limit. Read more on https://twitter.com/elonmusk/status/1675187969420828672?s=46.
#
# Got some tweets, saving to file...
# Error parsing response json: {"_type":"Response","_guid":"response@7f1233c3e56c8c0ae01ae9123a1c74f6"}
# Most likely, you have already exceeded the Twitter rate limit. Read more on https://twitter.com/elonmusk/status/1675187969420828672?s=46.
#
# Got some tweets, saving to file...
# Error parsing response json: {"_type":"Response","_guid":"response@5b3f4e9e95e01537df63544e045514e2"}
# Most likely, you have already exceeded the Twitter rate limit. Read more on https://twitter.com/elonmusk/status/1675187969420828672?s=46.
#
# Got some tweets, saving to file...
# Error parsing response json: {"_type":"Response","_guid":"response@fe7cf41f0dae43f8c7ff0945e4de93b4"}
# Most likely, you have already exceeded the Twitter rate limit. Read more on https://twitter.com/elonmusk/status/1675187969420828672?s=46.
#
# Got some tweets, saving to file...
# Error parsing response json: {"_type":"Response","_guid":"response@51e3a28c2f826ee57cad270f770ac91b"}
# Most likely, you have already exceeded the Twitter rate limit. Read more on https://twitter.com/elonmusk/status/1675187969420828672?s=46.
#
# Got some tweets, saving to file...
# Error parsing response json: {"_type":"Response","_guid":"response@ca4ef4ef6008bb2b9c3266ee31d41d2c"}
# Most likely, you have already exceeded the Twitter rate limit. Read more on https://twitter.com/elonmusk/status/1675187969420828672?s=46.
#
# Got some tweets, saving to file...
# Error parsing response json: {"_type":"Response","_guid":"response@a396997da1cbe8ecb977d23426116b7e"}
# Most likely, you have already exceeded the Twitter rate limit. Read more on https://twitter.com/elonmusk/status/1675187969420828672?s=46.
#
# Got some tweets, saving to file...
# Error parsing response json: {"_type":"Response","_guid":"response@af3243dd085c4ab1416e22d13fb9a30c"}
# Most likely, you have already exceeded the Twitter rate limit. Read more on https://twitter.com/elonmusk/status/1675187969420828672?s=46.
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/gibran.csv
# Total tweets saved: 663
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/gibran.csv
# Total tweets saved: 678
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/gibran.csv
# Total tweets saved: 696
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/gibran.csv
# Total tweets saved: 712
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/gibran.csv
# Total tweets saved: 731
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/gibran.csv
# Total tweets saved: 747
#
# --Taking a break, waiting for 10 seconds...
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/gibran.csv
# Total tweets saved: 763
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/gibran.csv
# Total tweets saved: 782
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/gibran.csv
# Total tweets saved: 800
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/gibran.csv
# Total tweets saved: 816
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/gibran.csv
# Total tweets saved: 830
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/gibran.csv
# Total tweets saved: 846
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/gibran.csv
# Total tweets saved: 862
#
# --Taking a break, waiting for 10 seconds...
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/gibran.csv
# Total tweets saved: 882
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/gibran.csv
# Total tweets saved: 901
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/gibran.csv
# Total tweets saved: 915
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/gibran.csv
# Total tweets saved: 930
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/gibran.csv
# Total tweets saved: 946
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/gibran.csv
# Total tweets saved: 963
#
# --Taking a break, waiting for 10 seconds...
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/gibran.csv
# Total tweets saved: 983
# Scrolling more...
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/gibran.csv
# Total tweets saved: 1000
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/gibran.csv
# Total tweets saved: 1019
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/gibran.csv
# Total tweets saved: 1035
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/gibran.csv
# Total tweets saved: 1052
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/gibran.csv
# Total tweets saved: 1070
#
# --Taking a break, waiting for 10 seconds...
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/gibran.csv
# Total tweets saved: 1089
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/gibran.csv
# Total tweets saved: 1108
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/gibran.csv
# Total tweets saved: 1125
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/gibran.csv
# Total tweets saved: 1142
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/gibran.csv
# Total tweets saved: 1156
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/gibran.csv
# Total tweets saved: 1171
#
# --Taking a break, waiting for 10 seconds...
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/gibran.csv
# Total tweets saved: 1188
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/gibran.csv
# Total tweets saved: 1206
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/gibran.csv
# Total tweets saved: 1222
# Scrolling more...
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/gibran.csv
# Total tweets saved: 1240
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/gibran.csv
# Total tweets saved: 1256
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/gibran.csv
# Total tweets saved: 1271
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/gibran.csv
# Total tweets saved: 1287
#
# --Taking a break, waiting for 10 seconds...
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/gibran.csv
# Total tweets saved: 1304
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/gibran.csv
# Total tweets saved: 1321
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/gibran.csv
# Total tweets saved: 1339
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/gibran.csv
# Total tweets saved: 1355
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/gibran.csv
# Total tweets saved: 1375
# Scrolling more...
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/gibran.csv
# Total tweets saved: 1395
#
# --Taking a break, waiting for 10 seconds...
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/gibran.csv
# Total tweets saved: 1412
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/gibran.csv
# Total tweets saved: 1429
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/gibran.csv
# Total tweets saved: 1444
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/gibran.csv
# Total tweets saved: 1461
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/gibran.csv
# Total tweets saved: 1478
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/gibran.csv
# Total tweets saved: 1495
#
# Got some tweets, saving to file...
# Error parsing response json: {"_type":"Response","_guid":"response@f07c07868cf92d3a4742066d694c00c4"}
# Most likely, you have already exceeded the Twitter rate limit. Read more on https://twitter.com/elonmusk/status/1675187969420828672?s=46.
#
# Got some tweets, saving to file...
# Error parsing response json: {"_type":"Response","_guid":"response@33a908c4e3e0d654cac17fdceb0b2209"}
# Most likely, you have already exceeded the Twitter rate limit. Read more on https://twitter.com/elonmusk/status/1675187969420828672?s=46.
#
# Got some tweets, saving to file...
# Error parsing response json: {"_type":"Response","_guid":"response@0b9ee4a6f78880b6fbd28a6cbadba8d1"}
# Most likely, you have already exceeded the Twitter rate limit. Read more on https://twitter.com/elonmusk/status/1675187969420828672?s=46.
#
# Got some tweets, saving to file...
# Error parsing response json: {"_type":"Response","_guid":"response@1ad63ddd6ddaa79fa4fa229ef4f57397"}
# Most likely, you have already exceeded the Twitter rate limit. Read more on https://twitter.com/elonmusk/status/1675187969420828672?s=46.
#
# Got some tweets, saving to file...
# Error parsing response json: {"_type":"Response","_guid":"response@08804c8f660b6d73c845dcc6d4031386"}
# Most likely, you have already exceeded the Twitter rate limit. Read more on https://twitter.com/elonmusk/status/1675187969420828672?s=46.
#
# Got some tweets, saving to file...
# Error parsing response json: {"_type":"Response","_guid":"response@ee673b9067670479a349370bd3ab6641"}
# Most likely, you have already exceeded the Twitter rate limit. Read more on https://twitter.com/elonmusk/status/1675187969420828672?s=46.
#
# Got some tweets, saving to file...
# Error parsing response json: {"_type":"Response","_guid":"response@84ae8a7f89ee61e295d8de621c206e8e"}
# Most likely, you have already exceeded the Twitter rate limit. Read more on https://twitter.com/elonmusk/status/1675187969420828672?s=46.
#
# Got some tweets, saving to file...
# Error parsing response json: {"_type":"Response","_guid":"response@ed80fd4103d83a9af8127f7a351c9cc9"}
# Most likely, you have already exceeded the Twitter rate limit. Read more on https://twitter.com/elonmusk/status/1675187969420828672?s=46.
#
# Got some tweets, saving to file...
# Error parsing response json: {"_type":"Response","_guid":"response@9139589b16a1b32004382d5f8c67ac6e"}
# Most likely, you have already exceeded the Twitter rate limit. Read more on https://twitter.com/elonmusk/status/1675187969420828672?s=46.
#
# Got some tweets, saving to file...
# Error parsing response json: {"_type":"Response","_guid":"response@12baca93dd7a54f7260596a143e885f5"}
# Most likely, you have already exceeded the Twitter rate limit. Read more on https://twitter.com/elonmusk/status/1675187969420828672?s=46.
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/gibran.csv
# Total tweets saved: 1511
#
# --Taking a break, waiting for 10 seconds...
# Already got 1511 tweets, done scrolling...

# %%
import pandas as pd

# Specify the path to your CSV file
file_path = f"tweets-data/{filename}"

# Read the CSV file into a pandas DataFrame
df = pd.read_csv(file_path, delimiter=";")

# Display the DataFrame
display(df)
# Out:
#                           created_at               id_str  \
# 0     Tue Oct 17 16:30:24 +0000 2023  1714317948943503763
# 1     Tue Oct 17 16:30:14 +0000 2023  1714317907080147201
# 2     Tue Oct 17 16:30:09 +0000 2023  1714317885873774759
# 3     Tue Oct 17 16:30:06 +0000 2023  1714317876352655382
# 4     Tue Oct 17 16:30:01 +0000 2023  1714317853091147886
# ...                              ...                  ...
# 1506  Tue Oct 17 14:25:59 +0000 2023  1714286638992597093
# 1507  Tue Oct 17 14:25:52 +0000 2023  1714286608844034177
# 1508  Tue Oct 17 14:25:50 +0000 2023  1714286602602815681
# 1509  Tue Oct 17 14:25:45 +0000 2023  1714286580092055769
# 1510  Tue Oct 17 14:25:45 +0000 2023  1714286579538407508
#
#                                               full_text  quote_count  \
# 0     @Dennysiregar7 Jadi maksud lo @gibran_tweet da...            0
# 1     @AntonKu73047372 @gibran_tweet @ganjarpranowo ...            0
# 2     Bakal plot twist klo dah ribut2 1 Indonesia ta...            0
# 3     Sebaiknya Gibran @gibran_tweet, walikota Solo ...            0
# 4     @Anak__Ogi @gibran_tweet @kaesangp Kl tiba2 be...            0
# ...                                                 ...          ...
# 1506  @WagimanDeep212_ @gibran_tweet Seri kududukan ...            0
# 1507  Halo om mas walkot @gibran_tweet ! Pesan leluh...            0
# 1508  #KamiSenang   Ganjar Pranowo Presiden + Gibran...            0
# 1509  @KakekHalal Gue akan tagih lu.. Kakek. Lu udah...            0
# 1510  Adanya keputusan MK menjadi angin segar bagi a...            0
#
#       reply_count  retweet_count  favorite_count lang          user_id_str  \
# 0               0              0               0   in            894971184
# 1               0              0               0   in            278039207
# 2               0              0               0   in            942573866
# 3               0              0               0   in   829504976724520960
# 4               0              0               0   in  1557531074632495106
# ...           ...            ...             ...  ...                  ...
# 1506            0              0               0   in  1305141635991306240
# 1507            0              0               0   in            218477659
# 1508            0              0               0   in  1017758611420864513
# 1509            0              0               0   in  1326612023174590465
# 1510            0              0               0   in            971454180
#
#       conversation_id_str         username  \
# 0     1714058146480632259       RoyKimochi
# 1     1713963277171179819        Megatop99
# 2     1714317885873774759        Bang_Nago
# 3     1714317876352655382  stopngetwitdulu
# 4     1714174156387107008         xxxpolll
# ...                   ...              ...
# 1506  1714251668299362429  Soewarn21036904
# 1507  1714286608844034177       intanalyze
# 1508  1714286602602815681  Haro_Rajagukguk
# 1509  1714245592162165200        BatuKepla
# 1510  1714286579538407508   Bimasakti66123
#
#                                               tweet_url
# 0     https://twitter.com/RoyKimochi/status/17143179...
# 1     https://twitter.com/Megatop99/status/171431790...
# 2     https://twitter.com/Bang_Nago/status/171431788...
# 3     https://twitter.com/stopngetwitdulu/status/171...
# 4     https://twitter.com/xxxpolll/status/1714317853...
# ...                                                 ...
# 1506  https://twitter.com/Soewarn21036904/status/171...
# 1507  https://twitter.com/intanalyze/status/17142866...
# 1508  https://twitter.com/Haro_Rajagukguk/status/171...
# 1509  https://twitter.com/BatuKepla/status/171428658...
# 1510  https://twitter.com/Bimasakti66123/status/1714...
#
# [1511 rows x 12 columns]

# %%
# Cek jumlah data yang didapatkan

num_tweets = len(df)
print(f"Jumlah tweet dalam dataframe adalah {num_tweets}.")
# Out:
# Jumlah tweet dalam dataframe adalah 1511.
